# %% [markdown]
# # KAIROS Benchmark Evaluation
#
# **This notebook produces the metrics reported in README.**
#
# It compares the KAIROS Hybrid Ensemble against baseline Logistic Regression and Random Forest models on the UCI Adult dataset.
